# %%
import pandas as pd

df = pd.read_csv('./parsed_emails.csv')

# %%
print df
# Out:
#       DocNumber        date                sender              receiver  \
# 0     C05739545  09/12/2012         Jake Sullivan                     H
# 1     C05739546  03/03/2011                   NaN                     H
# 2     C05739547  09/12/2012          Cheryl Mills                    ;H
# 3     C05739550  09/12/2012          Cheryl Mills                     H
# 4     C05739554  03/11/2011       Hillary Clinton          Abedin, Huma
# 5     C05739559  09/12/2012       Hillary Clinton     Russorv@state.gov
# 6     C05739560  09/12/2012          Cheryl Mills                     H
# 7     C05739561  03/11/2011       Hillary Clinton          Abedin, Huma
# 8     C05739562  09/12/2012         Jake Sullivan                     H
# 9     C05739563  09/12/2012                   NaN                     H
# 10    C05739564  03/13/2011         Jake Sullivan                     H
# 11    C05739565  09/12/2012                   NaN                     H
# ...
